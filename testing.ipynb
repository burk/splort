# %%
import splort
import numpy as np
import chess

# %%
reload(splort)
# Out:
# <module 'splort' from 'splort.py'>

# %%
board = chess.Board()

# %%
move = list(board.legal_moves)[0]

# %%
test = splort.Move(None, board)

# %%
test.score
# Out:
# 31.836421432760638

# %%
test.deeper(board)
# Out:
# deeper called at depth 0
# self.move is None
# subtree is []
# OK, at lowest depth
# Board is now:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# Appended 20 things
# Getting out of deeper, board is:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# POPPED

# %%
print test
# Out:
# 2: None, score 31.8364214328
# 0: b1a3, score 52.989057111
# 0: b1c3, score 44.2839756002
# 0: g1f3, score 49.2016808224
# 0: g1h3, score 38.6119890399
# 0: a2a3, score 47.6399940465
# 0: b2b3, score 40.6091666884
# 0: c2c3, score 39.8461774634
# 0: d2d3, score 39.421675456
# 0: e2e3, score 43.160366904
# 0: f2f3, score 48.8457947455
# 0: g2g3, score 42.0051813422
# 0: h2h3, score 45.4163587267
# 0: a2a4, score 40.4813618194
# 0: b2b4, score 41.9821196081
# 0: c2c4, score 41.1555634843
# 0: d2d4, score 42.7072589014
# 0: e2e4, score 43.9843758106
# 0: f2f4, score 40.8039271679
# 0: g2g4, score 40.7843222239
# 0: h2h4, score 35.2930523792

# %%
test.print_greedy_line(board)
# Out:
# Move 1: None
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# Move 2: b1a3
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# N . . . . . . .
# P P P P P P P P
# R . B Q K B N R

# %%
test.deeper(board)
# Out:
# deeper called at depth 2
# self.move is None
# subtree is [<splort.Move object at 0x7fa5dac3f9d0>, <splort.Move object at 0x7fa5dac3fa50>, <splort.Move object at 0x7fa5dac3f210>, <splort.Move object at 0x7fa5dac3f410>, <splort.Move object at 0x7fa5dac3f190>, <splort.Move object at 0x7fa5dac3f890>, <splort.Move object at 0x7fa5dac3fad0>, <splort.Move object at 0x7fa5dac3fb10>, <splort.Move object at 0x7fa5dac3ff10>, <splort.Move object at 0x7fa5dac3f3d0>, <splort.Move object at 0x7fa5dac3f350>, <splort.Move object at 0x7fa5dada7b50>, <splort.Move object at 0x7fa5dada7710>, <splort.Move object at 0x7fa5dada7790>, <splort.Move object at 0x7fa5dada7810>, <splort.Move object at 0x7fa5dada7890>, <splort.Move object at 0x7fa5dada7910>, <splort.Move object at 0x7fa5dada7990>, <splort.Move object at 0x7fa5dada79d0>, <splort.Move object at 0x7fa5dada7a90>]
# We have to go deeper, board is
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# ...

# %%
print test
# Out:
# 3: None, score 31.8364214328
# 2: b1a3, score 52.989057111
# 0: b8a6, score 36.9984199038
# 0: b8c6, score 41.2825689118
# 0: g8f6, score 40.9452590907
# 0: g8h6, score 39.5429419851
# 0: a7a6, score 42.1277207335
# 0: b7b6, score 42.0684616738
# 0: c7c6, score 42.8535555162
# 0: d7d6, score 48.7517446519
# 0: e7e6, score 35.7618465959
# 0: f7f6, score 42.1736349218
# 0: g7g6, score 40.7850527754
# 0: h7h6, score 37.1855949779
# 0: a7a5, score 39.6547645319
# 0: b7b5, score 46.8112299734
# 0: c7c5, score 46.2972807526
# 0: d7d5, score 44.5380663151
# 0: e7e5, score 43.8561562342
# 0: f7f5, score 38.5654562081
# 0: g7g5, score 37.5872497317
# 0: h7h5, score 47.7938325622
# 2: b1c3, score 44.2839756002
# 0: b8a6, score 42.6409359583
# 0: b8c6, score 41.2678893205
# 0: g8f6, score 36.5835091847
# 0: g8h6, score 44.361219531
# 0: a7a6, score 38.8160393586
# 0: b7b6, score 40.5813868043
# 0: c7c6, score 40.5468611519
# 0: d7d6, score 39.9244021065
# 0: e7e6, score 46.2876755171
# ...

# %%
print board
test.print_greedy_line(board)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# Move 1: None
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# Move 2: b1a3
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# N . . . . . . .
# P P P P P P P P
# R . B Q K B N R
# Move 2: d7d6
# r n b q k b n r
# p p p . p p p p
# . . . p . . . .
# . . . . . . . .
# . . . . . . . .
# N . . . . . . .
# P P P P P P P P
# R . B Q K B N R

# %%
print board
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
